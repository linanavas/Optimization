# %%
import numpy as np
from geneticalgorithm import geneticalgorithm as ga

# %%
def f(x):
    # Negative sign to maximize
    # pen is a penalization if constraints are not met

    pen = 0

    if not -x[0] + 2 * x[0] * x[1] <= 8:
        pen = np.inf
    if not 2 * x[0] + x[1] <= 14:
        pen = np.inf
    if not 2 * x[0] - x[1] <= 10:
        pen = np.inf

    return -(x[0] + x[0] * x[1]) + pen


varbounds = np.array([[0, 10], [0, 10]])
vartype = np.array([["int"], ["real"]])

model = ga(
    function=f, dimension=2, variable_type_mixed=vartype, variable_boundaries=varbounds
)

# %%
model.run()
# Out:
# |_________________________________________________ 2.5% GA is running...
# ||________________________________________________ 3.7% GA is running...
# /workspaces/optimization/myenv/lib/python3.10/site-packages/geneticalgorithm/geneticalgorithm.py:353: RuntimeWarning: invalid value encountered in subtract
#   normobj=maxnorm-normobj+1
#  The best solution found:
#  [5.        1.2935228]
#
#  Objective function:
#  -11.467613981871324
